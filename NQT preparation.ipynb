# %%
arr = [4,5,0,1,9,0,5,0,0,0,0]

pos = 0  # position for next non-zero

for i in range(len(arr)):
    if arr[i] != 0:
        arr[pos], arr[i] = arr[i], arr[pos]
        pos += 1
print(arr)
# Out:
# [4, 5, 1, 9, 5, 0, 0, 0, 0, 0, 0]

# %%
l=int(input())
string=input()
right=0
max_counts=0
ctr=0
for i in range(le   n(string)-l):
    tp=string[i:i+l]
    ctr=0
    for i in tp:
        if i=='a':
            ctr+=1
    if ctr>max_counts:
        max_counts=ctr
print(max_counts)
# Out:
# 1
